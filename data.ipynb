# %% [markdown]
# # [Github Profile]( https://github.com/muneeb61/DataSet.git)

# %% [markdown]
# ### Data_Set

# %%
import pandas as pd

# %%
df = pd.read_csv("laptop_purchase_data_india.csv")
df
# Out:
#      Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 0      CUST00001   56    True       Pune          Low        Online
# 1      CUST00002   46    True    Kolkata       Medium        Online
# 2      CUST00003   32    True  Bangalore          Low        Online
# 3      CUST00004   25    True     Jaipur       Medium       Offline
# 4      CUST00005   38    True       Pune         High        Online
# ...          ...  ...     ...        ...          ...           ...
# 4995   CUST04996   32    True       Pune          Low        Online
# 4996   CUST04997   36    True      Delhi       Medium       Offline
# 4997   CUST04998   52    True    Chennai          Low        Online
# 4998   CUST04999   34    True  Hyderabad       Medium        Online
# 4999   CUST05000   52    True    Kolkata         High        Online
#
#      Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 0               Dell     30K-50K          UPI               Rare
# ...

# %% [markdown]
# ### Data Load

# %% [markdown]
# #### 1. Inspecting the Data

# %%
df[2:6]     ##Indexing
# Out:
#   Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 2   CUST00003   32    True  Bangalore          Low        Online
# 3   CUST00004   25    True     Jaipur       Medium       Offline
# 4   CUST00005   38    True       Pune         High        Online
# 5   CUST00006   56    True  Ahmedabad         High        Online
#
#   Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 2         Samsung    80K-1.2L          UPI         Occasional
# 3         Samsung   Below 30K  Credit Card               Rare
# 4             MSI    80K-1.2L         Cash               Rare
# 5            Acer     30K-50K          EMI         Occasional
#
#    Satisfaction_Rating  Muneeb
# 2                    3      48
# 3                    4      48
# 4                    3      48
# 5                    4      48

# %%
df.head(5)
# Out:
#   Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 0   CUST00001   56    True       Pune          Low        Online
# 1   CUST00002   46    True    Kolkata       Medium        Online
# 2   CUST00003   32    True  Bangalore          Low        Online
# 3   CUST00004   25    True     Jaipur       Medium       Offline
# 4   CUST00005   38    True       Pune         High        Online
#
#   Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 0            Dell     30K-50K          UPI               Rare
# 1             MSI   Below 30K         Cash         Occasional
# 2         Samsung    80K-1.2L          UPI         Occasional
# 3         Samsung   Below 30K  Credit Card               Rare
# 4             MSI    80K-1.2L         Cash               Rare
#
#    Satisfaction_Rating  Muneeb
# 0                    4      48
# 1                    2      48
# 2                    3      48
# 3                    4      48
# 4                    3      48

# %%
df.tail(5)
# Out:
#      Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 4995   CUST04996   32    True       Pune          Low        Online
# 4996   CUST04997   36    True      Delhi       Medium       Offline
# 4997   CUST04998   52    True    Chennai          Low        Online
# 4998   CUST04999   34    True  Hyderabad       Medium        Online
# 4999   CUST05000   52    True    Kolkata         High        Online
#
#      Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 4995           Apple   Below 30K  Credit Card               Rare
# 4996            Dell     50K-80K         Cash         Occasional
# 4997          Lenovo    80K-1.2L         Cash               Rare
# 4998           Apple     30K-50K          UPI         Occasional
# 4999            Acer     30K-50K  Credit Card               Rare
#
#       Satisfaction_Rating  Muneeb
# 4995                    4      48
# 4996                    3      48
# 4997                    2      48
# ...

# %%
df.sample(6)     ## Random
# Out:
#      Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 4943   CUST04944   18    True    Kolkata          Low        Online
# 1132   CUST01133   20    True      Delhi          Low        Online
# 600    CUST00601   54    True  Hyderabad       Medium        Online
# 1258   CUST01259   52    True     Jaipur       Medium        Online
# 2441   CUST02442   38    True     Mumbai       Medium       Offline
# 2824   CUST02825   38    True      Delhi       Medium        Online
#
#      Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 4943              HP    80K-1.2L   Debit Card               Rare
# 1132            Dell     50K-80K          EMI         Occasional
# 600               HP     50K-80K   Debit Card           Frequent
# 1258            Asus  Above 1.2L          UPI               Rare
# 2441             MSI     30K-50K          EMI               Rare
# 2824         Samsung  Above 1.2L  Credit Card               Rare
#
# ...

# %% [markdown]
# #### 2. Checking the Structure

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Customer_ID          5000 non-null   object
#  1   Age                  5000 non-null   int64
#  2   Gender               5000 non-null   bool
#  3   City                 5000 non-null   object
#  4   Income_Level         5000 non-null   object
#  5   Purchase_Mode        5000 non-null   object
#  6   Brand_Purchased      5000 non-null   object
#  7   Price_Range          5000 non-null   object
#  8   Payment_Mode         5000 non-null   object
#  9   Purchase_Frequency   5000 non-null   object
#  10  Satisfaction_Rating  5000 non-null   int64
#  11  Muneeb               5000 non-null   int64
# dtypes: bool(1), int64(3), object(8)
# memory usage: 434.7+ KB

# %%
df[["Age", "Gender"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     5000 non-null   int64
#  1   Gender  5000 non-null   bool
# dtypes: bool(1), int64(1)
# memory usage: 44.1 KB

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'City', 'Income_Level', 'Purchase_Mode',
#        'Brand_Purchased', 'Price_Range', 'Payment_Mode', 'Purchase_Frequency',
#        'Satisfaction_Rating', 'Muneeb'],
#       dtype='object')

# %% [markdown]
# #### 3. Basic Calculations

# %%
df.sum()
# Out:
# Customer_ID            CUST00001CUST00002CUST00003CUST00004CUST00005C...
# Age                                                               193311
# Gender                                                              5000
# City                   PuneKolkataBangaloreJaipurPuneAhmedabadHyderab...
# Income_Level           LowMediumLowMediumHighHighMediumLowLowMediumLo...
# Purchase_Mode          OnlineOnlineOnlineOfflineOnlineOnlineOfflineOf...
# Brand_Purchased        DellMSISamsungSamsungMSIAcerLenovoLenovoAppleL...
# Price_Range            30K-50KBelow 30K80K-1.2LBelow 30K80K-1.2L30K-5...
# Payment_Mode           UPICashUPICredit CardCashEMICredit CardUPIEMIC...
# Purchase_Frequency     RareOccasionalOccasionalRareRareOccasionalRare...
# Satisfaction_Rating                                                14971
# Muneeb                                                            240000
# dtype: object

# %%
df.min()
# Out:
# Customer_ID            CUST00001
# Age                           18
# Gender                      True
# City                   Ahmedabad
# Income_Level                High
# Purchase_Mode            Offline
# Brand_Purchased             Acer
# Price_Range              30K-50K
# Payment_Mode                Cash
# Purchase_Frequency      Frequent
# Satisfaction_Rating            1
# Muneeb                        48
# dtype: object

# %%
df.max()
# Out:
# Customer_ID            CUST05000
# Age                           59
# Gender                      True
# City                        Pune
# Income_Level              Medium
# Purchase_Mode             Online
# Brand_Purchased          Samsung
# Price_Range            Below 30K
# Payment_Mode                 UPI
# Purchase_Frequency          Rare
# Satisfaction_Rating            5
# Muneeb                        48
# dtype: object

# %%
df["Age"].mean()   ##just work on numeric values
# Out:
# 38.6622

# %% [markdown]
# #### 4. Descriptive Statistics: A branch of statistics that involves summarizing, organizing, and presenting data meaningfully and concisely.

# %%
df.describe()
# Out:
#                Age  Satisfaction_Rating  Muneeb
# count  5000.000000          5000.000000  5000.0
# mean     38.662200             2.994200    48.0
# std      12.028492             1.416957     0.0
# min      18.000000             1.000000    48.0
# 25%      28.000000             2.000000    48.0
# 50%      39.000000             3.000000    48.0
# 75%      49.000000             4.000000    48.0
# max      59.000000             5.000000    48.0

# %%
df.describe(include= "all")
# Out:
#        Customer_ID          Age Gender     City Income_Level Purchase_Mode  \
# count         5000  5000.000000   5000     5000         5000          5000
# unique        5000          NaN      1        9            3             2
# top      CUST00001          NaN   True  Chennai       Medium        Online
# freq             1          NaN   5000      576         2540          3405
# mean           NaN    38.662200    NaN      NaN          NaN           NaN
# std            NaN    12.028492    NaN      NaN          NaN           NaN
# min            NaN    18.000000    NaN      NaN          NaN           NaN
# 25%            NaN    28.000000    NaN      NaN          NaN           NaN
# 50%            NaN    39.000000    NaN      NaN          NaN           NaN
# 75%            NaN    49.000000    NaN      NaN          NaN           NaN
# max            NaN    59.000000    NaN      NaN          NaN           NaN
#
# ...

# %%
df.nunique()     ## To count the unique items
# Out:
# Customer_ID            5000
# Age                      42
# Gender                    1
# City                      9
# Income_Level              3
# Purchase_Mode             2
# Brand_Purchased           8
# Price_Range               5
# Payment_Mode              5
# Purchase_Frequency        3
# Satisfaction_Rating       5
# Muneeb                    1
# dtype: int64

# %%
df["Gender"].value_counts()    ## To count number of items in that column
# Out:
# Gender
# True    5000
# Name: count, dtype: int64

# %% [markdown]
# #### 5. Viewing the Data

# %%
df.loc[78, 'Age']      ## To find the specific cell in your data_base and based on the label.
# Out:
# 46

# %%
df.iloc[2645, 7]      ## It finds the specific cell in the data_base butt by its position.
# Out:
# '30K-50K'

# %% [markdown]
# #### 6. Quick Visualization

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['City'].value_counts().plot(kind= 'bar')     ## Bar Graph vertically
# Out:
# <Axes: xlabel='City'>

# %%
df['City'].value_counts().plot(kind= 'barh', figsize= (10,5))   ## Bar Graph Horizontally
# Out:
# <Axes: ylabel='City'>

# %%
df['City'].value_counts().plot(kind= "line", color= "red")    ## line Graph
# Out:
# <Axes: xlabel='City'>

# %%
df['City'].value_counts().plot(kind= "hist", color= "red")    ## Histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['City'].value_counts().plot(kind= "box", color= "red", title= "Cities")   ## Box Plot
# Out:
# <Axes: title={'center': 'Cities'}>

# %%
df['City'].value_counts().plot(kind= "pie", color= "red", title= "Cities", legend= 'yes')   ## Pie chart of the Regions
# Out:
# <Axes: title={'center': 'Cities'}, ylabel='count'>

# %%
df['City'].value_counts().plot(kind= "density", color= "red", title= "City")    ## Density Graph, kde
# Out:
# <Axes: title={'center': 'City'}, ylabel='Density'>

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### 1. Handle Missing Data

# %%
df.isnull()      ## checks for the null values
# Out:
#       Customer_ID    Age  Gender   City  Income_Level  Purchase_Mode  \
# 0           False  False   False  False         False          False
# 1           False  False   False  False         False          False
# 2           False  False   False  False         False          False
# 3           False  False   False  False         False          False
# 4           False  False   False  False         False          False
# ...           ...    ...     ...    ...           ...            ...
# 4995        False  False   False  False         False          False
# 4996        False  False   False  False         False          False
# 4997        False  False   False  False         False          False
# 4998        False  False   False  False         False          False
# 4999        False  False   False  False         False          False
#
#       Brand_Purchased  Price_Range  Payment_Mode  Purchase_Frequency  \
# ...

# %%
df['Gender'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: Gender, Length: 5000, dtype: bool

# %%
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df.notnull()    ## Used to find the values that are not null.
# Out:
#       Customer_ID   Age  Gender  City  Income_Level  Purchase_Mode  \
# 0            True  True    True  True          True           True
# 1            True  True    True  True          True           True
# 2            True  True    True  True          True           True
# 3            True  True    True  True          True           True
# 4            True  True    True  True          True           True
# ...           ...   ...     ...   ...           ...            ...
# 4995         True  True    True  True          True           True
# 4996         True  True    True  True          True           True
# 4997         True  True    True  True          True           True
# 4998         True  True    True  True          True           True
# 4999         True  True    True  True          True           True
#
#       Brand_Purchased  Price_Range  Payment_Mode  Purchase_Frequency  \
# 0                True         True          True                True
# ...

# %%
df['Muneeb']= 48
df
# Out:
#      Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 0      CUST00001   56    True       Pune          Low        Online
# 1      CUST00002   46    True    Kolkata       Medium        Online
# 2      CUST00003   32    True  Bangalore          Low        Online
# 3      CUST00004   25    True     Jaipur       Medium       Offline
# 4      CUST00005   38    True       Pune         High        Online
# ...          ...  ...     ...        ...          ...           ...
# 4995   CUST04996   32    True       Pune          Low        Online
# 4996   CUST04997   36    True      Delhi       Medium       Offline
# 4997   CUST04998   52    True    Chennai          Low        Online
# 4998   CUST04999   34    True  Hyderabad       Medium        Online
# 4999   CUST05000   52    True    Kolkata         High        Online
#
#      Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 0               Dell     30K-50K          UPI               Rare
# ...

# %% [markdown]
# #### 2. Removing Data

# %%
df.duplicated()    ## to find any kind of duplication in data_set
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df['Customer_ID'].duplicated()   ## just check the duplicates Element
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: Customer_ID, Length: 5000, dtype: bool

# %%
df['Customer_ID'].duplicated().sum()
# Out:
# 0

# %%
df['Brand_Purchased'].drop_duplicates()  ## To drop / Eliminate the duplicate data.
# Out:
# 0        Dell
# 1         MSI
# 2     Samsung
# 5        Acer
# 6      Lenovo
# 8       Apple
# 10         HP
# 23       Asus
# Name: Brand_Purchased, dtype: object

# %%
df.drop(['Gender'], axis= 1)   ## inplace=true
# Out:
#      Customer_ID  Age       City Income_Level Purchase_Mode Brand_Purchased  \
# 0      CUST00001   56       Pune          Low        Online            Dell
# 1      CUST00002   46    Kolkata       Medium        Online             MSI
# 2      CUST00003   32  Bangalore          Low        Online         Samsung
# 3      CUST00004   25     Jaipur       Medium       Offline         Samsung
# 4      CUST00005   38       Pune         High        Online             MSI
# ...          ...  ...        ...          ...           ...             ...
# 4995   CUST04996   32       Pune          Low        Online           Apple
# 4996   CUST04997   36      Delhi       Medium       Offline            Dell
# 4997   CUST04998   52    Chennai          Low        Online          Lenovo
# 4998   CUST04999   34  Hyderabad       Medium        Online           Apple
# 4999   CUST05000   52    Kolkata         High        Online            Acer
#
# ...

# %% [markdown]
# #### 3. Renaming Columns:

# %%
df.rename(columns= {'City':'State', 'Customer_ID':'ID'})
# Out:
#              ID  Age  Gender      State Income_Level Purchase_Mode  \
# 0     CUST00001   56    True       Pune          Low        Online
# 1     CUST00002   46    True    Kolkata       Medium        Online
# 2     CUST00003   32    True  Bangalore          Low        Online
# 3     CUST00004   25    True     Jaipur       Medium       Offline
# 4     CUST00005   38    True       Pune         High        Online
# ...         ...  ...     ...        ...          ...           ...
# 4995  CUST04996   32    True       Pune          Low        Online
# 4996  CUST04997   36    True      Delhi       Medium       Offline
# 4997  CUST04998   52    True    Chennai          Low        Online
# 4998  CUST04999   34    True  Hyderabad       Medium        Online
# 4999  CUST05000   52    True    Kolkata         High        Online
#
#      Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 0               Dell     30K-50K          UPI               Rare
# ...

# %% [markdown]
# #### 4. Converting Data_type

# %%
df['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   bool
# dtypes: bool(1)
# memory usage: 5.0 KB

# %%
df['Gender'] = df['Gender'].astype(bool)   ##to change data_type

# %%
df['Gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 5000 entries, 0 to 4999
# Series name: Gender
# Non-Null Count  Dtype
# --------------  -----
# 5000 non-null   bool
# dtypes: bool(1)
# memory usage: 5.0 KB

# %% [markdown]
# ### Data Preprocessing

# %%
df.groupby('Gender').sum()
# Out:
#                                               Customer_ID     Age  \
# Gender
# True    CUST00001CUST00002CUST00003CUST00004CUST00005C...  193311
#
#                                                      City  \
# Gender
# True    PuneKolkataBangaloreJaipurPuneAhmedabadHyderab...
#
#                                              Income_Level  \
# Gender
# True    LowMediumLowMediumHighHighMediumLowLowMediumLo...
#
#                                             Purchase_Mode  \
# Gender
# True    OnlineOnlineOnlineOfflineOnlineOnlineOfflineOf...
#
#                                           Brand_Purchased  \
# Gender
# True    DellMSISamsungSamsungMSIAcerLenovoLenovoAppleL...
#
#                                               Price_Range  \
# Gender
# True    30K-50KBelow 30K80K-1.2LBelow 30K80K-1.2L30K-5...
#
#                                              Payment_Mode  \
# Gender
# True    UPICashUPICredit CardCashEMICredit CardUPIEMIC...
#
# ...

# %% [markdown]
# ### Data Augmentation

# %%
df.loc[df.index.repeat(2)]      ## To repeat the the colum or Data_set
# Out:
#      Customer_ID  Age  Gender       City Income_Level Purchase_Mode  \
# 0      CUST00001   56    True       Pune          Low        Online
# 0      CUST00001   56    True       Pune          Low        Online
# 1      CUST00002   46    True    Kolkata       Medium        Online
# 1      CUST00002   46    True    Kolkata       Medium        Online
# 2      CUST00003   32    True  Bangalore          Low        Online
# ...          ...  ...     ...        ...          ...           ...
# 4997   CUST04998   52    True    Chennai          Low        Online
# 4998   CUST04999   34    True  Hyderabad       Medium        Online
# 4998   CUST04999   34    True  Hyderabad       Medium        Online
# 4999   CUST05000   52    True    Kolkata         High        Online
# 4999   CUST05000   52    True    Kolkata         High        Online
#
#      Brand_Purchased Price_Range Payment_Mode Purchase_Frequency  \
# 0               Dell     30K-50K          UPI               Rare
# ...

# %%
df1= pd.DataFrame({
    "Name": ['Muneeb','Hassaan'],
    "Rank":[ 4, 2],
})
df1
# Out:
#       Name  Rank
# 0   Muneeb     4
# 1  Hassaan     2

# %%
df2= pd.DataFrame({
    "Name": ['Akbar', 'Awais'],
    "Rank": [ 1, 3]
})
df2
# Out:
#     Name  Rank
# 0  Akbar     1
# 1  Awais     3

# %%
pd.concat([df1,df2])
# Out:
#       Name  Rank
# 0   Muneeb     4
# 1  Hassaan     2
# 0    Akbar     1
# 1    Awais     3

# %%
x= pd.DataFrame({
    "Name": ['Muneeb', 'Awais'],
    "Class": ['1st Year', '3rd Year']
})
x
# Out:
#      Name     Class
# 0  Muneeb  1st Year
# 1   Awais  3rd Year

# %%
y= pd.DataFrame({
    "Name": ['Muneeb', 'Awais'],
    "Roll No": [48, 21]
})
y
# Out:
#      Name  Roll No
# 0  Muneeb       48
# 1   Awais       21

# %%
pd.merge(x ,y , on="Name")
# Out:
#      Name     Class  Roll No
# 0  Muneeb  1st Year       48
# 1   Awais  3rd Year       21

# %% [markdown]
# ### Data Save

# %%
df.to_csv("laptop_purchase_data_india.csv", index= False)
